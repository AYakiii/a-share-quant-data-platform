# %% [markdown]
# # 02 - Signal research (Colab)
#
# Run signal diagnostics on real feature-store partitions.

# %%
# !pip -q install -r requirements.txt
import os
os.environ['PYTHONPATH']='src'

# %%
# !python -m qsys.utils.signal_engine_example --feature-root data/processed/feature_store/v1 --head 10

# %%
# !python -m qsys.utils.research_diagnostics_example --feature-root data/processed/feature_store/v1

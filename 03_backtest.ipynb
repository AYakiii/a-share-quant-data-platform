# %% [markdown]
# # 03 - Backtest (Colab)
#
# Run backtest and constraint impact analysis from real feature-store data.

# %%
# !pip -q install -r requirements.txt
import os
os.environ['PYTHONPATH']='src'

# %%
# !python -m qsys.utils.backtest_example --feature-root data/processed/feature_store/v1 --top-n 30

# %%
# !python -m qsys.utils.constraint_impact_example --feature-root data/processed/feature_store/v1 --top-n 30

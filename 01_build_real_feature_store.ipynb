# %% [markdown]
# # 01 - Build real feature store (Colab)
#
# This notebook builds `data/processed/feature_store/v1` from AkShare real A-share daily data.

# %%
# !pip -q install -r requirements.txt

# %%
import os
os.environ['PYTHONPATH']='src'

# %%
# !python -m qsys.utils.build_real_feature_store \
  --feature-root data/processed/feature_store/v1 \
  --start-date 2020-01-01 \
  --limit 300
